# %%
#Import necessary packages 
import os
import requests
import subprocess
from Bio.PDB import MMCIFParser, PDBIO

# %%
#Code for finding AlphaFold structures, if available, using the code provided below. These AlphaFold structures will later be used to extract features to feed to the model for predictions.

#First read FASTA file and extract the protein sequence using the header as a guide
def read_fasta(fasta_file):
    sequences = []
    with open(fasta_file, 'r') as file:
        for line in file:
            line = line.strip()
            if line.startswith('>'):
                header_parts = line[1:].split('|')
                if len(header_parts) >= 2:
                    uniprot_id = header_parts[1]
                    sequences.append({'header': uniprot_id, 'sequence': ''})
            else:
                if sequences:
                    sequences[-1]['sequence'] += line
    return sequences

# %%
#First try extracting the PDB CIF file using the given URL

def get_predicted_structure(uniprot_id, api_key, output_dir):
    url = f'https://alphafold.ebi.ac.uk/api/prediction/{uniprot_id}?key={api_key}'
    response = requests.get(url)
    
    if response.status_code == 200:
        prediction_data = response.json()
        if prediction_data and isinstance(prediction_data, list) and len(prediction_data) > 0:
            prediction_entry = prediction_data[0]  # Get the first entry from the list
            cif_url = prediction_entry.get('cifUrl')
            if cif_url:
                cif_response = requests.get(cif_url)
                if cif_response.status_code == 200:
                    cif_data = cif_response.text
                    cif_filename = os.path.join(output_dir, f"{uniprot_id}.cif")
                    with open(cif_filename, 'w') as cif_file:
                        cif_file.write(cif_data)
                    print(f"Successfully downloaded predicted structure for UniProt ID {uniprot_id} to {cif_filename}")
                    return cif_filename
                else:
                    print(f"Failed to retrieve predicted structure for UniProt ID {uniprot_id}. Status code: {cif_response.status_code}")
            else:
                print(f"No CIF URL found for UniProt ID {uniprot_id}")
        else:
            print(f"Empty or invalid prediction data received for UniProt ID {uniprot_id}")
    else:
        print(f"Failed to retrieve predicted structure for UniProt ID {uniprot_id}. Status code: {response.status_code}")
    return None

# %%
#Process predicted structure by saving it in the output directory

def process_predicted_structure(uniprot_id, api_key, output_dir):
    url = f'https://alphafold.ebi.ac.uk/api/prediction/{uniprot_id}?key={api_key}'
    response = requests.get(url)
    
    if response.status_code == 200:
        prediction_data = response.json()
        if prediction_data and isinstance(prediction_data, list) and len(prediction_data) > 0:
            prediction_entry = prediction_data[0]  # Get the first entry from the list
            cif_url = prediction_entry.get('cifUrl')
            if cif_url:
                cif_response = requests.get(cif_url)
                if cif_response.status_code == 200:
                    cif_data = cif_response.text
                    cif_filename = os.path.join(output_dir, f"{uniprot_id}.cif")
                    with open(cif_filename, 'w') as cif_file:
                        cif_file.write(cif_data)
                    print(f"Successfully downloaded predicted structure for UniProt ID {uniprot_id} to {cif_filename}")
                    return cif_filename
                else:
                    print(f"Failed to retrieve predicted structure for UniProt ID {uniprot_id}. Status code: {cif_response.status_code}")
            else:
                print(f"No CIF URL found for UniProt ID {uniprot_id}")
        else:
            print(f"Empty or invalid prediction data received for UniProt ID {uniprot_id}")
    else:
        print(f"Failed to retrieve predicted structure for UniProt ID {uniprot_id}. Status code: {response.status_code}")
    return None

# %%
def find_homolog(sequence):
    # Perform a search for homologs using HHpred
    hhpred_url = "https://toolkit.tuebingen.mpg.de/api/hhpred"
    payload = {
        "query": sequence,
        "database": "uniclust30_2022_03",
        "n_hits": 1  # Number of hits to return
    }
    response = requests.post(hhpred_url, json=payload)

    if response.status_code == 200:
        result = response.json()
        # Extract information about the top hit
        top_hit = result.get('results', [])[0]  # Assuming at least one hit is returned
        hit_id = top_hit.get('id')
        hit_sequence = top_hit.get('alignment', {}).get('hit_sequence')
        hit_evalue = top_hit.get('evalue')
        return hit_id, hit_sequence, hit_evalue
    else:
        print("Error: Unable to retrieve homolog from HHpred")
        return None, None, None

# %%
def request_prediction(sequence):
    # Request protein structure prediction from AlphaFold
    alphafold_url = "https://alphafold.ebi.ac.uk/submit"
    payload = {
        "target": sequence
    }
    response = requests.post(alphafold_url, json=payload)

    if response.status_code == 200:
        prediction_id = response.json().get('prediction_id')
        return prediction_id
    else:
        print("Error: Unable to request protein structure prediction from AlphaFold")
        return None

# %%
def main(fasta_file_path, api_key, output_dir):
    sequences = read_fasta(fasta_file_path)
    for sequence_data in sequences:
        uniprot_id = sequence_data['header']
        mmcif_file = get_predicted_structure(uniprot_id, api_key, output_dir)
        if not mmcif_file:
            hit_id, hit_sequence, hit_evalue = find_homolog(sequence_data['sequence'])
            if hit_id and hit_sequence and hit_evalue:
                prediction_id = request_prediction(hit_sequence)
                if prediction_id:
                    print("AlphaFold prediction requested successfully. Prediction ID:", prediction_id)
            else:
                print("Error: Unable to find a homolog for the given sequence")
        else:
            print(f"Successfully downloaded predicted structure for UniProt ID {uniprot_id}")
            # Optionally, process the predicted structure here
            process_predicted_structure(uniprot_id, mmcif_file, output_dir)

# %%
if __name__ == "__main__":
    fasta_file_path = "idmapping_2024_03_23.fasta"
    #Write your own API key here after obtaining it from AlphaFold
    api_key = "AIzaSyCeurAJz7ZGjPQUtEaerUkBZ3TaBkXrY94"
    output_dir = "output_dir"
    main(fasta_file_path, api_key, output_dir)
# Out:
# Successfully downloaded predicted structure for UniProt ID Q14738 to output_dir/Q14738.cif
# Successfully downloaded predicted structure for UniProt ID Q14738
# Successfully downloaded predicted structure for UniProt ID Q14738 to output_dir/Q14738.cif
# Successfully downloaded predicted structure for UniProt ID Q13362 to output_dir/Q13362.cif
# Successfully downloaded predicted structure for UniProt ID Q13362
# Successfully downloaded predicted structure for UniProt ID Q13362 to output_dir/Q13362.cif
# Successfully downloaded predicted structure for UniProt ID Q9NRA8 to output_dir/Q9NRA8.cif
# Successfully downloaded predicted structure for UniProt ID Q9NRA8
# Successfully downloaded predicted structure for UniProt ID Q9NRA8 to output_dir/Q9NRA8.cif
# Successfully downloaded predicted structure for UniProt ID P42684 to output_dir/P42684.cif
# Successfully downloaded predicted structure for UniProt ID P42684
# Successfully downloaded predicted structure for UniProt ID P42684 to output_dir/P42684.cif
# Successfully downloaded predicted structure for UniProt ID Q4JIM5 to output_dir/Q4JIM5.cif
# Successfully downloaded predicted structure for UniProt ID Q4JIM5
# Successfully downloaded predicted structure for UniProt ID Q4JIM5 to output_dir/Q4JIM5.cif
# Successfully downloaded predicted structure for UniProt ID P55263 to output_dir/P55263.cif
# Successfully downloaded predicted structure for UniProt ID P55263
# Successfully downloaded predicted structure for UniProt ID P55263 to output_dir/P55263.cif
# Successfully downloaded predicted structure for UniProt ID P42568 to output_dir/P42568.cif
# Successfully downloaded predicted structure for UniProt ID P42568
# Successfully downloaded predicted structure for UniProt ID P42568 to output_dir/P42568.cif
# Failed to retrieve predicted structure for UniProt ID Q09666. Status code: 404
# Error: Unable to retrieve homolog from HHpred
# Error: Unable to find a homolog for the given sequence
# Successfully downloaded predicted structure for UniProt ID O95831 to output_dir/O95831.cif
# Successfully downloaded predicted structure for UniProt ID O95831
# Successfully downloaded predicted structure for UniProt ID O95831 to output_dir/O95831.cif
# Successfully downloaded predicted structure for UniProt ID Q96IF1 to output_dir/Q96IF1.cif
# Successfully downloaded predicted structure for UniProt ID Q96IF1
# Successfully downloaded predicted structure for UniProt ID Q96IF1 to output_dir/Q96IF1.cif
# Successfully downloaded predicted structure for UniProt ID Q9ULX6 to output_dir/Q9ULX6.cif
# Successfully downloaded predicted structure for UniProt ID Q9ULX6
# Successfully downloaded predicted structure for UniProt ID Q9ULX6 to output_dir/Q9ULX6.cif
# Successfully downloaded predicted structure for UniProt ID Q7Z6G8 to output_dir/Q7Z6G8.cif
# Successfully downloaded predicted structure for UniProt ID Q7Z6G8
# Successfully downloaded predicted structure for UniProt ID Q7Z6G8 to output_dir/Q7Z6G8.cif
# Successfully downloaded predicted structure for UniProt ID Q9BZZ5 to output_dir/Q9BZZ5.cif
# Successfully downloaded predicted structure for UniProt ID Q9BZZ5
# Successfully downloaded predicted structure for UniProt ID Q9BZZ5 to output_dir/Q9BZZ5.cif
# Successfully downloaded predicted structure for UniProt ID Q7Z2E3 to output_dir/Q7Z2E3.cif
# Successfully downloaded predicted structure for UniProt ID Q7Z2E3
# Successfully downloaded predicted structure for UniProt ID Q7Z2E3 to output_dir/Q7Z2E3.cif
# Successfully downloaded predicted structure for UniProt ID P54259 to output_dir/P54259.cif
# Successfully downloaded predicted structure for UniProt ID P54259
# Successfully downloaded predicted structure for UniProt ID P54259 to output_dir/P54259.cif
# Successfully downloaded predicted structure for UniProt ID P54253 to output_dir/P54253.cif
# Successfully downloaded predicted structure for UniProt ID P54253
# Successfully downloaded predicted structure for UniProt ID P54253 to output_dir/P54253.cif
# Successfully downloaded predicted structure for UniProt ID Q92560 to output_dir/Q92560.cif
# Successfully downloaded predicted structure for UniProt ID Q92560
# Successfully downloaded predicted structure for UniProt ID Q92560 to output_dir/Q92560.cif
# Successfully downloaded predicted structure for UniProt ID P54132 to output_dir/P54132.cif
# Successfully downloaded predicted structure for UniProt ID P54132
# Successfully downloaded predicted structure for UniProt ID P54132 to output_dir/P54132.cif
# Successfully downloaded predicted structure for UniProt ID O00327 to output_dir/O00327.cif
# Successfully downloaded predicted structure for UniProt ID O00327
# Successfully downloaded predicted structure for UniProt ID O00327 to output_dir/O00327.cif
# Successfully downloaded predicted structure for UniProt ID Q9WTL8 to output_dir/Q9WTL8.cif
# Successfully downloaded predicted structure for UniProt ID Q9WTL8
# Successfully downloaded predicted structure for UniProt ID Q9WTL8 to output_dir/Q9WTL8.cif
# Successfully downloaded predicted structure for UniProt ID P35226 to output_dir/P35226.cif
# Successfully downloaded predicted structure for UniProt ID P35226
# Successfully downloaded predicted structure for UniProt ID P35226 to output_dir/P35226.cif
# Successfully downloaded predicted structure for UniProt ID P25440 to output_dir/P25440.cif
# Successfully downloaded predicted structure for UniProt ID P25440
# Successfully downloaded predicted structure for UniProt ID P25440 to output_dir/P25440.cif
# Successfully downloaded predicted structure for UniProt ID Q9NPI1 to output_dir/Q9NPI1.cif
# Successfully downloaded predicted structure for UniProt ID Q9NPI1
# Successfully downloaded predicted structure for UniProt ID Q9NPI1 to output_dir/Q9NPI1.cif
# Successfully downloaded predicted structure for UniProt ID Q58F21 to output_dir/Q58F21.cif
# Successfully downloaded predicted structure for UniProt ID Q58F21
# Successfully downloaded predicted structure for UniProt ID Q58F21 to output_dir/Q58F21.cif
# Successfully downloaded predicted structure for UniProt ID O60566 to output_dir/O60566.cif
# Successfully downloaded predicted structure for UniProt ID O60566
# Successfully downloaded predicted structure for UniProt ID O60566 to output_dir/O60566.cif
# Successfully downloaded predicted structure for UniProt ID O43683 to output_dir/O43683.cif
# Successfully downloaded predicted structure for UniProt ID O43683
# Successfully downloaded predicted structure for UniProt ID O43683 to output_dir/O43683.cif
# Successfully downloaded predicted structure for UniProt ID Q8NG31 to output_dir/Q8NG31.cif
# Successfully downloaded predicted structure for UniProt ID Q8NG31
# Successfully downloaded predicted structure for UniProt ID Q8NG31 to output_dir/Q8NG31.cif
# Successfully downloaded predicted structure for UniProt ID Q6P1J9 to output_dir/Q6P1J9.cif
# Successfully downloaded predicted structure for UniProt ID Q6P1J9
# Successfully downloaded predicted structure for UniProt ID Q6P1J9 to output_dir/Q6P1J9.cif
# Successfully downloaded predicted structure for UniProt ID P38936 to output_dir/P38936.cif
# Successfully downloaded predicted structure for UniProt ID P38936
# Successfully downloaded predicted structure for UniProt ID P38936 to output_dir/P38936.cif
# Successfully downloaded predicted structure for UniProt ID P46527 to output_dir/P46527.cif
# Successfully downloaded predicted structure for UniProt ID P46527
# Successfully downloaded predicted structure for UniProt ID P46527 to output_dir/P46527.cif
# Successfully downloaded predicted structure for UniProt ID P46414 to output_dir/P46414.cif
# Successfully downloaded predicted structure for UniProt ID P46414
# Successfully downloaded predicted structure for UniProt ID P46414 to output_dir/P46414.cif
# Successfully downloaded predicted structure for UniProt ID Q03188 to output_dir/Q03188.cif
# Successfully downloaded predicted structure for UniProt ID Q03188
# Successfully downloaded predicted structure for UniProt ID Q03188 to output_dir/Q03188.cif
# Failed to retrieve predicted structure for UniProt ID P49454. Status code: 404
# Error: Unable to retrieve homolog from HHpred
# Error: Unable to find a homolog for the given sequence
# Successfully downloaded predicted structure for UniProt ID Q13352 to output_dir/Q13352.cif
# Successfully downloaded predicted structure for UniProt ID Q13352
# Successfully downloaded predicted structure for UniProt ID Q13352 to output_dir/Q13352.cif
# Successfully downloaded predicted structure for UniProt ID Q71F23 to output_dir/Q71F23.cif
# Successfully downloaded predicted structure for UniProt ID Q71F23
# Successfully downloaded predicted structure for UniProt ID Q71F23 to output_dir/Q71F23.cif
# Successfully downloaded predicted structure for UniProt ID O15516 to output_dir/O15516.cif
# Successfully downloaded predicted structure for UniProt ID O15516
# Successfully downloaded predicted structure for UniProt ID O15516 to output_dir/O15516.cif
# Successfully downloaded predicted structure for UniProt ID O08785 to output_dir/O08785.cif
# Successfully downloaded predicted structure for UniProt ID O08785
# Successfully downloaded predicted structure for UniProt ID O08785 to output_dir/O08785.cif
# Successfully downloaded predicted structure for UniProt ID P10909 to output_dir/P10909.cif
# Successfully downloaded predicted structure for UniProt ID P10909
# Successfully downloaded predicted structure for UniProt ID P10909 to output_dir/P10909.cif
# Successfully downloaded predicted structure for UniProt ID P23528 to output_dir/P23528.cif
# Successfully downloaded predicted structure for UniProt ID P23528
# Successfully downloaded predicted structure for UniProt ID P23528 to output_dir/P23528.cif
# Successfully downloaded predicted structure for UniProt ID Q8WYA6 to output_dir/Q8WYA6.cif
# Successfully downloaded predicted structure for UniProt ID Q8WYA6
# Successfully downloaded predicted structure for UniProt ID Q8WYA6 to output_dir/Q8WYA6.cif
# Successfully downloaded predicted structure for UniProt ID O60716 to output_dir/O60716.cif
# Successfully downloaded predicted structure for UniProt ID O60716
# Successfully downloaded predicted structure for UniProt ID O60716 to output_dir/O60716.cif
# Successfully downloaded predicted structure for UniProt ID P30999 to output_dir/P30999.cif
# Successfully downloaded predicted structure for UniProt ID P30999
# Successfully downloaded predicted structure for UniProt ID P30999 to output_dir/P30999.cif
# Successfully downloaded predicted structure for UniProt ID Q13620 to output_dir/Q13620.cif
# Successfully downloaded predicted structure for UniProt ID Q13620
# Successfully downloaded predicted structure for UniProt ID Q13620 to output_dir/Q13620.cif
# Successfully downloaded predicted structure for UniProt ID Q14118 to output_dir/Q14118.cif
# Successfully downloaded predicted structure for UniProt ID Q14118
# Successfully downloaded predicted structure for UniProt ID Q14118 to output_dir/Q14118.cif
# Successfully downloaded predicted structure for UniProt ID Q62165 to output_dir/Q62165.cif
# Successfully downloaded predicted structure for UniProt ID Q62165
# Successfully downloaded predicted structure for UniProt ID Q62165 to output_dir/Q62165.cif
# Successfully downloaded predicted structure for UniProt ID Q9UER7 to output_dir/Q9UER7.cif
# Successfully downloaded predicted structure for UniProt ID Q9UER7
# Successfully downloaded predicted structure for UniProt ID Q9UER7 to output_dir/Q9UER7.cif
# Successfully downloaded predicted structure for UniProt ID O75398 to output_dir/O75398.cif
# Successfully downloaded predicted structure for UniProt ID O75398
# Successfully downloaded predicted structure for UniProt ID O75398 to output_dir/O75398.cif
# Successfully downloaded predicted structure for UniProt ID P35659 to output_dir/P35659.cif
# Successfully downloaded predicted structure for UniProt ID P35659
# Successfully downloaded predicted structure for UniProt ID P35659 to output_dir/P35659.cif
# Successfully downloaded predicted structure for UniProt ID P60981 to output_dir/P60981.cif
# Successfully downloaded predicted structure for UniProt ID P60981
# Successfully downloaded predicted structure for UniProt ID P60981 to output_dir/P60981.cif
# Successfully downloaded predicted structure for UniProt ID Q9H2U1 to output_dir/Q9H2U1.cif
# Successfully downloaded predicted structure for UniProt ID Q9H2U1
# Successfully downloaded predicted structure for UniProt ID Q9H2U1 to output_dir/Q9H2U1.cif
# Successfully downloaded predicted structure for UniProt ID Q08211 to output_dir/Q08211.cif
# Successfully downloaded predicted structure for UniProt ID Q08211
# Successfully downloaded predicted structure for UniProt ID Q08211 to output_dir/Q08211.cif
# Successfully downloaded predicted structure for UniProt ID O70133 to output_dir/O70133.cif
# Successfully downloaded predicted structure for UniProt ID O70133
# Successfully downloaded predicted structure for UniProt ID O70133 to output_dir/O70133.cif
# Successfully downloaded predicted structure for UniProt ID Q9BTC0 to output_dir/Q9BTC0.cif
# Successfully downloaded predicted structure for UniProt ID Q9BTC0
# Successfully downloaded predicted structure for UniProt ID Q9BTC0 to output_dir/Q9BTC0.cif
# Successfully downloaded predicted structure for UniProt ID P26358 to output_dir/P26358.cif
# Successfully downloaded predicted structure for UniProt ID P26358
# Successfully downloaded predicted structure for UniProt ID P26358 to output_dir/P26358.cif
# Successfully downloaded predicted structure for UniProt ID P13864 to output_dir/P13864.cif
# Successfully downloaded predicted structure for UniProt ID P13864
# Successfully downloaded predicted structure for UniProt ID P13864 to output_dir/P13864.cif
# Successfully downloaded predicted structure for UniProt ID Q9NZJ0 to output_dir/Q9NZJ0.cif
# Successfully downloaded predicted structure for UniProt ID Q9NZJ0
# Successfully downloaded predicted structure for UniProt ID Q9NZJ0 to output_dir/Q9NZJ0.cif
# Successfully downloaded predicted structure for UniProt ID Q92630 to output_dir/Q92630.cif
# Successfully downloaded predicted structure for UniProt ID Q92630
# Successfully downloaded predicted structure for UniProt ID Q92630 to output_dir/Q92630.cif
# Successfully downloaded predicted structure for UniProt ID Q9H8V3 to output_dir/Q9H8V3.cif
# Successfully downloaded predicted structure for UniProt ID Q9H8V3
# Successfully downloaded predicted structure for UniProt ID Q9H8V3 to output_dir/Q9H8V3.cif
# Successfully downloaded predicted structure for UniProt ID P55199 to output_dir/P55199.cif
# Successfully downloaded predicted structure for UniProt ID P55199
# Successfully downloaded predicted structure for UniProt ID P55199 to output_dir/P55199.cif
# Successfully downloaded predicted structure for UniProt ID Q09472 to output_dir/Q09472.cif
# Successfully downloaded predicted structure for UniProt ID Q09472
# Successfully downloaded predicted structure for UniProt ID Q09472 to output_dir/Q09472.cif
# Successfully downloaded predicted structure for UniProt ID Q15303 to output_dir/Q15303.cif
# Successfully downloaded predicted structure for UniProt ID Q15303
# Successfully downloaded predicted structure for UniProt ID Q15303 to output_dir/Q15303.cif
# Successfully downloaded predicted structure for UniProt ID Q61527 to output_dir/Q61527.cif
# Successfully downloaded predicted structure for UniProt ID Q61527
# Successfully downloaded predicted structure for UniProt ID Q61527 to output_dir/Q61527.cif
# Successfully downloaded predicted structure for UniProt ID P07992 to output_dir/P07992.cif
# Successfully downloaded predicted structure for UniProt ID P07992
# Successfully downloaded predicted structure for UniProt ID P07992 to output_dir/P07992.cif
# Successfully downloaded predicted structure for UniProt ID P18074 to output_dir/P18074.cif
# Successfully downloaded predicted structure for UniProt ID P18074
# Successfully downloaded predicted structure for UniProt ID P18074 to output_dir/P18074.cif
# Successfully downloaded predicted structure for UniProt ID P19447 to output_dir/P19447.cif
# Successfully downloaded predicted structure for UniProt ID P19447
# Successfully downloaded predicted structure for UniProt ID P19447 to output_dir/P19447.cif
# Successfully downloaded predicted structure for UniProt ID P28715 to output_dir/P28715.cif
# Successfully downloaded predicted structure for UniProt ID P28715
# Successfully downloaded predicted structure for UniProt ID P28715 to output_dir/P28715.cif
# Successfully downloaded predicted structure for UniProt ID Q03468 to output_dir/Q03468.cif
# Successfully downloaded predicted structure for UniProt ID Q03468
# Successfully downloaded predicted structure for UniProt ID Q03468 to output_dir/Q03468.cif
# Successfully downloaded predicted structure for UniProt ID Q03112 to output_dir/Q03112.cif
# Successfully downloaded predicted structure for UniProt ID Q03112
# Successfully downloaded predicted structure for UniProt ID Q03112 to output_dir/Q03112.cif
# Successfully downloaded predicted structure for UniProt ID Q01844 to output_dir/Q01844.cif
# Successfully downloaded predicted structure for UniProt ID Q01844
# Successfully downloaded predicted structure for UniProt ID Q01844 to output_dir/Q01844.cif
# Successfully downloaded predicted structure for UniProt ID P04117 to output_dir/P04117.cif
# Successfully downloaded predicted structure for UniProt ID P04117
# Successfully downloaded predicted structure for UniProt ID P04117 to output_dir/P04117.cif
# Successfully downloaded predicted structure for UniProt ID O15360 to output_dir/O15360.cif
# Successfully downloaded predicted structure for UniProt ID O15360
# Successfully downloaded predicted structure for UniProt ID O15360 to output_dir/O15360.cif
# Successfully downloaded predicted structure for UniProt ID Q9BX63 to output_dir/Q9BX63.cif
# Successfully downloaded predicted structure for UniProt ID Q9BX63
# Successfully downloaded predicted structure for UniProt ID Q9BX63 to output_dir/Q9BX63.cif
# Successfully downloaded predicted structure for UniProt ID P03968 to output_dir/P03968.cif
# Successfully downloaded predicted structure for UniProt ID P03968
# Successfully downloaded predicted structure for UniProt ID P03968 to output_dir/P03968.cif
# Successfully downloaded predicted structure for UniProt ID P05230 to output_dir/P05230.cif
# Successfully downloaded predicted structure for UniProt ID P05230
# Successfully downloaded predicted structure for UniProt ID P05230 to output_dir/P05230.cif
# Successfully downloaded predicted structure for UniProt ID Q12778 to output_dir/Q12778.cif
# Successfully downloaded predicted structure for UniProt ID Q12778
# Successfully downloaded predicted structure for UniProt ID Q12778 to output_dir/Q12778.cif
# Successfully downloaded predicted structure for UniProt ID Q9R1E0 to output_dir/Q9R1E0.cif
# Successfully downloaded predicted structure for UniProt ID Q9R1E0
# Successfully downloaded predicted structure for UniProt ID Q9R1E0 to output_dir/Q9R1E0.cif
# Successfully downloaded predicted structure for UniProt ID O43524 to output_dir/O43524.cif
# Successfully downloaded predicted structure for UniProt ID O43524
# Successfully downloaded predicted structure for UniProt ID O43524 to output_dir/O43524.cif
# Successfully downloaded predicted structure for UniProt ID O15117 to output_dir/O15117.cif
# Successfully downloaded predicted structure for UniProt ID O15117
# Successfully downloaded predicted structure for UniProt ID O15117 to output_dir/O15117.cif
# Successfully downloaded predicted structure for UniProt ID P34947 to output_dir/P34947.cif
# Successfully downloaded predicted structure for UniProt ID P34947
# Successfully downloaded predicted structure for UniProt ID P34947 to output_dir/P34947.cif
# Successfully downloaded predicted structure for UniProt ID Q9UHL9 to output_dir/Q9UHL9.cif
# Successfully downloaded predicted structure for UniProt ID Q9UHL9
# Successfully downloaded predicted structure for UniProt ID Q9UHL9 to output_dir/Q9UHL9.cif
# Successfully downloaded predicted structure for UniProt ID P78347 to output_dir/P78347.cif
# Successfully downloaded predicted structure for UniProt ID P78347
# Successfully downloaded predicted structure for UniProt ID P78347 to output_dir/P78347.cif
# Successfully downloaded predicted structure for UniProt ID P51858 to output_dir/P51858.cif
# Successfully downloaded predicted structure for UniProt ID P51858
# Successfully downloaded predicted structure for UniProt ID P51858 to output_dir/P51858.cif
# Successfully downloaded predicted structure for UniProt ID Q16665 to output_dir/Q16665.cif
# Successfully downloaded predicted structure for UniProt ID Q16665
# Successfully downloaded predicted structure for UniProt ID Q16665 to output_dir/Q16665.cif
# Successfully downloaded predicted structure for UniProt ID Q61221 to output_dir/Q61221.cif
# Successfully downloaded predicted structure for UniProt ID Q61221
# Successfully downloaded predicted structure for UniProt ID Q61221 to output_dir/Q61221.cif
# Successfully downloaded predicted structure for UniProt ID P20823 to output_dir/P20823.cif
# Successfully downloaded predicted structure for UniProt ID P20823
# Successfully downloaded predicted structure for UniProt ID P20823 to output_dir/P20823.cif
# Successfully downloaded predicted structure for UniProt ID P07910 to output_dir/P07910.cif
# Successfully downloaded predicted structure for UniProt ID P07910
# Successfully downloaded predicted structure for UniProt ID P07910 to output_dir/P07910.cif
# Successfully downloaded predicted structure for UniProt ID O43390 to output_dir/O43390.cif
# Successfully downloaded predicted structure for UniProt ID O43390
# Successfully downloaded predicted structure for UniProt ID O43390 to output_dir/O43390.cif
# Successfully downloaded predicted structure for UniProt ID Q7Z5L9 to output_dir/Q7Z5L9.cif
# Successfully downloaded predicted structure for UniProt ID Q7Z5L9
# Successfully downloaded predicted structure for UniProt ID Q7Z5L9 to output_dir/Q7Z5L9.cif
# Successfully downloaded predicted structure for UniProt ID Q28653 to output_dir/Q28653.cif
# Successfully downloaded predicted structure for UniProt ID Q28653
# Successfully downloaded predicted structure for UniProt ID Q28653 to output_dir/Q28653.cif
# Successfully downloaded predicted structure for UniProt ID Q28651 to output_dir/Q28651.cif
# Successfully downloaded predicted structure for UniProt ID Q28651
# Successfully downloaded predicted structure for UniProt ID Q28651 to output_dir/Q28651.cif
# Successfully downloaded predicted structure for UniProt ID Q9EST3 to output_dir/Q9EST3.cif
# Successfully downloaded predicted structure for UniProt ID Q9EST3
# Successfully downloaded predicted structure for UniProt ID Q9EST3 to output_dir/Q9EST3.cif
# Failed to retrieve predicted structure for UniProt ID P55262. Status code: 404
# Error: Unable to retrieve homolog from HHpred
# Error: Unable to find a homolog for the given sequence
# Successfully downloaded predicted structure for UniProt ID P55264 to output_dir/P55264.cif
# Successfully downloaded predicted structure for UniProt ID P55264
# Successfully downloaded predicted structure for UniProt ID P55264 to output_dir/P55264.cif
# Successfully downloaded predicted structure for UniProt ID Q64640 to output_dir/Q64640.cif
# Successfully downloaded predicted structure for UniProt ID Q64640
# Successfully downloaded predicted structure for UniProt ID Q64640 to output_dir/Q64640.cif
# Successfully downloaded predicted structure for UniProt ID Q8WTP8 to output_dir/Q8WTP8.cif
# Successfully downloaded predicted structure for UniProt ID Q8WTP8
# Successfully downloaded predicted structure for UniProt ID Q8WTP8 to output_dir/Q8WTP8.cif
# Successfully downloaded predicted structure for UniProt ID Q9CZI9 to output_dir/Q9CZI9.cif
# Successfully downloaded predicted structure for UniProt ID Q9CZI9
# Successfully downloaded predicted structure for UniProt ID Q9CZI9 to output_dir/Q9CZI9.cif
# Successfully downloaded predicted structure for UniProt ID Q5REE2 to output_dir/Q5REE2.cif
# Successfully downloaded predicted structure for UniProt ID Q5REE2
# Successfully downloaded predicted structure for UniProt ID Q5REE2 to output_dir/Q5REE2.cif
# Successfully downloaded predicted structure for UniProt ID B2GUW6 to output_dir/B2GUW6.cif
# Successfully downloaded predicted structure for UniProt ID B2GUW6
# Successfully downloaded predicted structure for UniProt ID B2GUW6 to output_dir/B2GUW6.cif
# Successfully downloaded predicted structure for UniProt ID A2AM29 to output_dir/A2AM29.cif
# Successfully downloaded predicted structure for UniProt ID A2AM29
# Successfully downloaded predicted structure for UniProt ID A2AM29 to output_dir/A2AM29.cif
# Successfully downloaded predicted structure for UniProt ID Q9Z0X1 to output_dir/Q9Z0X1.cif
# Successfully downloaded predicted structure for UniProt ID Q9Z0X1
# Successfully downloaded predicted structure for UniProt ID Q9Z0X1 to output_dir/Q9Z0X1.cif
# Successfully downloaded predicted structure for UniProt ID Q9JM53 to output_dir/Q9JM53.cif
# Successfully downloaded predicted structure for UniProt ID Q9JM53
# Successfully downloaded predicted structure for UniProt ID Q9JM53 to output_dir/Q9JM53.cif
# Successfully downloaded predicted structure for UniProt ID Q9Z0E3 to output_dir/Q9Z0E3.cif
# Successfully downloaded predicted structure for UniProt ID Q9Z0E3
# Successfully downloaded predicted structure for UniProt ID Q9Z0E3 to output_dir/Q9Z0E3.cif
# Successfully downloaded predicted structure for UniProt ID Q91XC0 to output_dir/Q91XC0.cif
# Successfully downloaded predicted structure for UniProt ID Q91XC0
# Successfully downloaded predicted structure for UniProt ID Q91XC0 to output_dir/Q91XC0.cif
# Successfully downloaded predicted structure for UniProt ID Q5U2Z2 to output_dir/Q5U2Z2.cif
# Successfully downloaded predicted structure for UniProt ID Q5U2Z2
# Successfully downloaded predicted structure for UniProt ID Q5U2Z2 to output_dir/Q5U2Z2.cif
# Successfully downloaded predicted structure for UniProt ID Q5VK71 to output_dir/Q5VK71.cif
# Successfully downloaded predicted structure for UniProt ID Q5VK71
# Successfully downloaded predicted structure for UniProt ID Q5VK71 to output_dir/Q5VK71.cif
# Successfully downloaded predicted structure for UniProt ID O43823 to output_dir/O43823.cif
# Successfully downloaded predicted structure for UniProt ID O43823
# Successfully downloaded predicted structure for UniProt ID O43823 to output_dir/O43823.cif
# Successfully downloaded predicted structure for UniProt ID Q9DBR0 to output_dir/Q9DBR0.cif
# Successfully downloaded predicted structure for UniProt ID Q9DBR0
# Successfully downloaded predicted structure for UniProt ID Q9DBR0 to output_dir/Q9DBR0.cif
# Successfully downloaded predicted structure for UniProt ID Q63014 to output_dir/Q63014.cif
# Successfully downloaded predicted structure for UniProt ID Q63014
# Successfully downloaded predicted structure for UniProt ID Q63014 to output_dir/Q63014.cif
# Successfully downloaded predicted structure for UniProt ID Q9H9L7 to output_dir/Q9H9L7.cif
# Successfully downloaded predicted structure for UniProt ID Q9H9L7
# Successfully downloaded predicted structure for UniProt ID Q9H9L7 to output_dir/Q9H9L7.cif
# Successfully downloaded predicted structure for UniProt ID Q99LF1 to output_dir/Q99LF1.cif
# Successfully downloaded predicted structure for UniProt ID Q99LF1
# Successfully downloaded predicted structure for UniProt ID Q99LF1 to output_dir/Q99LF1.cif
# Successfully downloaded predicted structure for UniProt ID A8YXY8 to output_dir/A8YXY8.cif
# Successfully downloaded predicted structure for UniProt ID A8YXY8
# Successfully downloaded predicted structure for UniProt ID A8YXY8 to output_dir/A8YXY8.cif
# Successfully downloaded predicted structure for UniProt ID Q53H80 to output_dir/Q53H80.cif
# Successfully downloaded predicted structure for UniProt ID Q53H80
# Successfully downloaded predicted structure for UniProt ID Q53H80 to output_dir/Q53H80.cif
# Successfully downloaded predicted structure for UniProt ID B1AXD8 to output_dir/B1AXD8.cif
# Successfully downloaded predicted structure for UniProt ID B1AXD8
# Successfully downloaded predicted structure for UniProt ID B1AXD8 to output_dir/B1AXD8.cif
# Successfully downloaded predicted structure for UniProt ID Q25C79 to output_dir/Q25C79.cif
# Successfully downloaded predicted structure for UniProt ID Q25C79
# Successfully downloaded predicted structure for UniProt ID Q25C79 to output_dir/Q25C79.cif
# Successfully downloaded predicted structure for UniProt ID Q9R0L7 to output_dir/Q9R0L7.cif
# Successfully downloaded predicted structure for UniProt ID Q9R0L7
# Successfully downloaded predicted structure for UniProt ID Q9R0L7 to output_dir/Q9R0L7.cif
# Successfully downloaded predicted structure for UniProt ID P0C6S7 to output_dir/P0C6S7.cif
# Successfully downloaded predicted structure for UniProt ID P0C6S7
# Successfully downloaded predicted structure for UniProt ID P0C6S7 to output_dir/P0C6S7.cif
# Successfully downloaded predicted structure for UniProt ID O35841 to output_dir/O35841.cif
# Successfully downloaded predicted structure for UniProt ID O35841
# Successfully downloaded predicted structure for UniProt ID O35841 to output_dir/O35841.cif
# Successfully downloaded predicted structure for UniProt ID Q5R644 to output_dir/Q5R644.cif
# Successfully downloaded predicted structure for UniProt ID Q5R644
# Successfully downloaded predicted structure for UniProt ID Q5R644 to output_dir/Q5R644.cif
# Successfully downloaded predicted structure for UniProt ID Q7YRZ2 to output_dir/Q7YRZ2.cif
# Successfully downloaded predicted structure for UniProt ID Q7YRZ2
# Successfully downloaded predicted structure for UniProt ID Q7YRZ2 to output_dir/Q7YRZ2.cif
# Successfully downloaded predicted structure for UniProt ID P61797 to output_dir/P61797.cif
# Successfully downloaded predicted structure for UniProt ID P61797
# Successfully downloaded predicted structure for UniProt ID P61797 to output_dir/P61797.cif
# Successfully downloaded predicted structure for UniProt ID Q9BGQ0 to output_dir/Q9BGQ0.cif
# Successfully downloaded predicted structure for UniProt ID Q9BGQ0
# Successfully downloaded predicted structure for UniProt ID Q9BGQ0 to output_dir/Q9BGQ0.cif
# Successfully downloaded predicted structure for UniProt ID Q7TQC5 to output_dir/Q7TQC5.cif
# Successfully downloaded predicted structure for UniProt ID Q7TQC5
# Successfully downloaded predicted structure for UniProt ID Q7TQC5 to output_dir/Q7TQC5.cif
# Successfully downloaded predicted structure for UniProt ID Q7YRZ1 to output_dir/Q7YRZ1.cif
# Successfully downloaded predicted structure for UniProt ID Q7YRZ1
# Successfully downloaded predicted structure for UniProt ID Q7YRZ1 to output_dir/Q7YRZ1.cif
# Successfully downloaded predicted structure for UniProt ID Q8K4H4 to output_dir/Q8K4H4.cif
# Successfully downloaded predicted structure for UniProt ID Q8K4H4
# Successfully downloaded predicted structure for UniProt ID Q8K4H4 to output_dir/Q8K4H4.cif
# Successfully downloaded predicted structure for UniProt ID Q7Z628 to output_dir/Q7Z628.cif
# Successfully downloaded predicted structure for UniProt ID Q7Z628
# Successfully downloaded predicted structure for UniProt ID Q7Z628 to output_dir/Q7Z628.cif
# Successfully downloaded predicted structure for UniProt ID Q9Z206 to output_dir/Q9Z206.cif
# Successfully downloaded predicted structure for UniProt ID Q9Z206
# Successfully downloaded predicted structure for UniProt ID Q9Z206 to output_dir/Q9Z206.cif
# Successfully downloaded predicted structure for UniProt ID O00192 to output_dir/O00192.cif
# Successfully downloaded predicted structure for UniProt ID O00192
# Successfully downloaded predicted structure for UniProt ID O00192 to output_dir/O00192.cif
# Successfully downloaded predicted structure for UniProt ID P98203 to output_dir/P98203.cif
# Successfully downloaded predicted structure for UniProt ID P98203
# Successfully downloaded predicted structure for UniProt ID P98203 to output_dir/P98203.cif
# Successfully downloaded predicted structure for UniProt ID P59598 to output_dir/P59598.cif
# Successfully downloaded predicted structure for UniProt ID P59598
# Successfully downloaded predicted structure for UniProt ID P59598 to output_dir/P59598.cif
# Successfully downloaded predicted structure for UniProt ID Q76L83 to output_dir/Q76L83.cif
# Successfully downloaded predicted structure for UniProt ID Q76L83
# Successfully downloaded predicted structure for UniProt ID Q76L83 to output_dir/Q76L83.cif
# Successfully downloaded predicted structure for UniProt ID Q8BZ32 to output_dir/Q8BZ32.cif
# Successfully downloaded predicted structure for UniProt ID Q8BZ32
# Successfully downloaded predicted structure for UniProt ID Q8BZ32 to output_dir/Q8BZ32.cif
# Successfully downloaded predicted structure for UniProt ID O35126 to output_dir/O35126.cif
# Successfully downloaded predicted structure for UniProt ID O35126
# Successfully downloaded predicted structure for UniProt ID O35126 to output_dir/O35126.cif
# Successfully downloaded predicted structure for UniProt ID Q5IS70 to output_dir/Q5IS70.cif
# Successfully downloaded predicted structure for UniProt ID Q5IS70
# Successfully downloaded predicted structure for UniProt ID Q5IS70 to output_dir/Q5IS70.cif
# Successfully downloaded predicted structure for UniProt ID P54258 to output_dir/P54258.cif
# Successfully downloaded predicted structure for UniProt ID P54258
# Successfully downloaded predicted structure for UniProt ID P54258 to output_dir/P54258.cif
# Successfully downloaded predicted structure for UniProt ID P54254 to output_dir/P54254.cif
# Successfully downloaded predicted structure for UniProt ID P54254
# Successfully downloaded predicted structure for UniProt ID P54254 to output_dir/P54254.cif
# Successfully downloaded predicted structure for UniProt ID Q63540 to output_dir/Q63540.cif
# Successfully downloaded predicted structure for UniProt ID Q63540
# Successfully downloaded predicted structure for UniProt ID Q63540 to output_dir/Q63540.cif
# Successfully downloaded predicted structure for UniProt ID A2VDM8 to output_dir/A2VDM8.cif
# Successfully downloaded predicted structure for UniProt ID A2VDM8
# Successfully downloaded predicted structure for UniProt ID A2VDM8 to output_dir/A2VDM8.cif
# Successfully downloaded predicted structure for UniProt ID Q99PU7 to output_dir/Q99PU7.cif
# Successfully downloaded predicted structure for UniProt ID Q99PU7
# Successfully downloaded predicted structure for UniProt ID Q99PU7 to output_dir/Q99PU7.cif
# Successfully downloaded predicted structure for UniProt ID D3ZHS6 to output_dir/D3ZHS6.cif
# Successfully downloaded predicted structure for UniProt ID D3ZHS6
# Successfully downloaded predicted structure for UniProt ID D3ZHS6 to output_dir/D3ZHS6.cif
# Successfully downloaded predicted structure for UniProt ID Q5H9F3 to output_dir/Q5H9F3.cif
# Successfully downloaded predicted structure for UniProt ID Q5H9F3
# Successfully downloaded predicted structure for UniProt ID Q5H9F3 to output_dir/Q5H9F3.cif
# Successfully downloaded predicted structure for UniProt ID O88700 to output_dir/O88700.cif
# Successfully downloaded predicted structure for UniProt ID O88700
# Successfully downloaded predicted structure for UniProt ID O88700 to output_dir/O88700.cif
# Successfully downloaded predicted structure for UniProt ID A0MLS5 to output_dir/A0MLS5.cif
# Successfully downloaded predicted structure for UniProt ID A0MLS5
# Successfully downloaded predicted structure for UniProt ID A0MLS5 to output_dir/A0MLS5.cif
# Successfully downloaded predicted structure for UniProt ID O88529 to output_dir/O88529.cif
# Successfully downloaded predicted structure for UniProt ID O88529
# Successfully downloaded predicted structure for UniProt ID O88529 to output_dir/O88529.cif
# Successfully downloaded predicted structure for UniProt ID Q91YA9 to output_dir/Q91YA9.cif
# Successfully downloaded predicted structure for UniProt ID Q91YA9
# Successfully downloaded predicted structure for UniProt ID Q91YA9 to output_dir/Q91YA9.cif
# Successfully downloaded predicted structure for UniProt ID Q5R4T2 to output_dir/Q5R4T2.cif
# Successfully downloaded predicted structure for UniProt ID Q5R4T2
# Successfully downloaded predicted structure for UniProt ID Q5R4T2 to output_dir/Q5R4T2.cif
# Successfully downloaded predicted structure for UniProt ID Q9EPW1 to output_dir/Q9EPW1.cif
# Successfully downloaded predicted structure for UniProt ID Q9EPW1
# Successfully downloaded predicted structure for UniProt ID Q9EPW1 to output_dir/Q9EPW1.cif
# Successfully downloaded predicted structure for UniProt ID Q8WYA1 to output_dir/Q8WYA1.cif
# Successfully downloaded predicted structure for UniProt ID Q8WYA1
# Successfully downloaded predicted structure for UniProt ID Q8WYA1 to output_dir/Q8WYA1.cif
# Successfully downloaded predicted structure for UniProt ID Q2VPD4 to output_dir/Q2VPD4.cif
# Successfully downloaded predicted structure for UniProt ID Q2VPD4
# Successfully downloaded predicted structure for UniProt ID Q2VPD4 to output_dir/Q2VPD4.cif
# Successfully downloaded predicted structure for UniProt ID Q32KX7 to output_dir/Q32KX7.cif
# Successfully downloaded predicted structure for UniProt ID Q32KX7
# Successfully downloaded predicted structure for UniProt ID Q32KX7 to output_dir/Q32KX7.cif
# Successfully downloaded predicted structure for UniProt ID Q9TST0 to output_dir/Q9TST0.cif
# Successfully downloaded predicted structure for UniProt ID Q9TST0
# Successfully downloaded predicted structure for UniProt ID Q9TST0 to output_dir/Q9TST0.cif
# Successfully downloaded predicted structure for UniProt ID P25916 to output_dir/P25916.cif
# Successfully downloaded predicted structure for UniProt ID P25916
# Successfully downloaded predicted structure for UniProt ID P25916 to output_dir/P25916.cif
# Successfully downloaded predicted structure for UniProt ID Q5R8L2 to output_dir/Q5R8L2.cif
# Successfully downloaded predicted structure for UniProt ID Q5R8L2
# Successfully downloaded predicted structure for UniProt ID Q5R8L2 to output_dir/Q5R8L2.cif
# Successfully downloaded predicted structure for UniProt ID Q01954 to output_dir/Q01954.cif
# Successfully downloaded predicted structure for UniProt ID Q01954
# Successfully downloaded predicted structure for UniProt ID Q01954 to output_dir/Q01954.cif
# Successfully downloaded predicted structure for UniProt ID O35914 to output_dir/O35914.cif
# Successfully downloaded predicted structure for UniProt ID O35914
# Successfully downloaded predicted structure for UniProt ID O35914 to output_dir/O35914.cif
# Failed to retrieve predicted structure for UniProt ID O54952. Status code: 404
# Error: Unable to retrieve homolog from HHpred
# Error: Unable to find a homolog for the given sequence
# Successfully downloaded predicted structure for UniProt ID Q32S26 to output_dir/Q32S26.cif
# Successfully downloaded predicted structure for UniProt ID Q32S26
# Successfully downloaded predicted structure for UniProt ID Q32S26 to output_dir/Q32S26.cif
# Successfully downloaded predicted structure for UniProt ID Q5TJG6 to output_dir/Q5TJG6.cif
# Successfully downloaded predicted structure for UniProt ID Q5TJG6
# Successfully downloaded predicted structure for UniProt ID Q5TJG6 to output_dir/Q5TJG6.cif
# Successfully downloaded predicted structure for UniProt ID Q7JJ13 to output_dir/Q7JJ13.cif
# Successfully downloaded predicted structure for UniProt ID Q7JJ13
# Successfully downloaded predicted structure for UniProt ID Q7JJ13 to output_dir/Q7JJ13.cif
# Successfully downloaded predicted structure for UniProt ID Q6MGA9 to output_dir/Q6MGA9.cif
# Successfully downloaded predicted structure for UniProt ID Q6MGA9
# Successfully downloaded predicted structure for UniProt ID Q6MGA9 to output_dir/Q6MGA9.cif
# Successfully downloaded predicted structure for UniProt ID O88665 to output_dir/O88665.cif
# Successfully downloaded predicted structure for UniProt ID O88665
# Successfully downloaded predicted structure for UniProt ID O88665 to output_dir/O88665.cif
# Successfully downloaded predicted structure for UniProt ID Q5R8B0 to output_dir/Q5R8B0.cif
# Successfully downloaded predicted structure for UniProt ID Q5R8B0
# Successfully downloaded predicted structure for UniProt ID Q5R8B0 to output_dir/Q5R8B0.cif
# Successfully downloaded predicted structure for UniProt ID Q4R8Y1 to output_dir/Q4R8Y1.cif
# Successfully downloaded predicted structure for UniProt ID Q4R8Y1
# Successfully downloaded predicted structure for UniProt ID Q4R8Y1 to output_dir/Q4R8Y1.cif
# Successfully downloaded predicted structure for UniProt ID Q91Y44 to output_dir/Q91Y44.cif
# Successfully downloaded predicted structure for UniProt ID Q91Y44
# Successfully downloaded predicted structure for UniProt ID Q91Y44 to output_dir/Q91Y44.cif
# Successfully downloaded predicted structure for UniProt ID D4A7T3 to output_dir/D4A7T3.cif
# Successfully downloaded predicted structure for UniProt ID D4A7T3
# Successfully downloaded predicted structure for UniProt ID D4A7T3 to output_dir/D4A7T3.cif
# Successfully downloaded predicted structure for UniProt ID O14981 to output_dir/O14981.cif
# Successfully downloaded predicted structure for UniProt ID O14981
# Successfully downloaded predicted structure for UniProt ID O14981 to output_dir/O14981.cif
# Successfully downloaded predicted structure for UniProt ID Q9Z1S0 to output_dir/Q9Z1S0.cif
# Successfully downloaded predicted structure for UniProt ID Q9Z1S0
# Successfully downloaded predicted structure for UniProt ID Q9Z1S0 to output_dir/Q9Z1S0.cif
# Successfully downloaded predicted structure for UniProt ID O08901 to output_dir/O08901.cif
# Successfully downloaded predicted structure for UniProt ID O08901
# Successfully downloaded predicted structure for UniProt ID O08901 to output_dir/O08901.cif
# Successfully downloaded predicted structure for UniProt ID Q2NKU3 to output_dir/Q2NKU3.cif
# Successfully downloaded predicted structure for UniProt ID Q2NKU3
# Successfully downloaded predicted structure for UniProt ID Q2NKU3 to output_dir/Q2NKU3.cif
# Successfully downloaded predicted structure for UniProt ID P41223 to output_dir/P41223.cif
# Successfully downloaded predicted structure for UniProt ID P41223
# Successfully downloaded predicted structure for UniProt ID P41223 to output_dir/P41223.cif
# Successfully downloaded predicted structure for UniProt ID Q6PGH1 to output_dir/Q6PGH1.cif
# Successfully downloaded predicted structure for UniProt ID Q6PGH1
# Successfully downloaded predicted structure for UniProt ID Q6PGH1 to output_dir/Q6PGH1.cif
# Successfully downloaded predicted structure for UniProt ID O70454 to output_dir/O70454.cif
# Successfully downloaded predicted structure for UniProt ID O70454
# Successfully downloaded predicted structure for UniProt ID O70454 to output_dir/O70454.cif
# Successfully downloaded predicted structure for UniProt ID Q865V6 to output_dir/Q865V6.cif
# Successfully downloaded predicted structure for UniProt ID Q865V6
# Successfully downloaded predicted structure for UniProt ID Q865V6 to output_dir/Q865V6.cif
# Successfully downloaded predicted structure for UniProt ID P40121 to output_dir/P40121.cif
# Successfully downloaded predicted structure for UniProt ID P40121
# Successfully downloaded predicted structure for UniProt ID P40121 to output_dir/P40121.cif
# Successfully downloaded predicted structure for UniProt ID P24452 to output_dir/P24452.cif
# Successfully downloaded predicted structure for UniProt ID P24452
# Successfully downloaded predicted structure for UniProt ID P24452 to output_dir/P24452.cif
# Successfully downloaded predicted structure for UniProt ID Q6AYC4 to output_dir/Q6AYC4.cif
# Successfully downloaded predicted structure for UniProt ID Q6AYC4
# Successfully downloaded predicted structure for UniProt ID Q6AYC4 to output_dir/Q6AYC4.cif
# Successfully downloaded predicted structure for UniProt ID Q66JQ7 to output_dir/Q66JQ7.cif
# Successfully downloaded predicted structure for UniProt ID Q66JQ7
# Successfully downloaded predicted structure for UniProt ID Q66JQ7 to output_dir/Q66JQ7.cif
# Successfully downloaded predicted structure for UniProt ID Q91ZF2 to output_dir/Q91ZF2.cif
# Successfully downloaded predicted structure for UniProt ID Q91ZF2
# Successfully downloaded predicted structure for UniProt ID Q91ZF2 to output_dir/Q91ZF2.cif
# Successfully downloaded predicted structure for UniProt ID D3ZZ07 to output_dir/D3ZZ07.cif
# Successfully downloaded predicted structure for UniProt ID D3ZZ07
# Successfully downloaded predicted structure for UniProt ID D3ZZ07 to output_dir/D3ZZ07.cif
# Successfully downloaded predicted structure for UniProt ID Q14781 to output_dir/Q14781.cif
# Successfully downloaded predicted structure for UniProt ID Q14781
# Successfully downloaded predicted structure for UniProt ID Q14781 to output_dir/Q14781.cif
# Successfully downloaded predicted structure for UniProt ID P30658 to output_dir/P30658.cif
# Successfully downloaded predicted structure for UniProt ID P30658
# Successfully downloaded predicted structure for UniProt ID P30658 to output_dir/P30658.cif
# Successfully downloaded predicted structure for UniProt ID Q6T8E9 to output_dir/Q6T8E9.cif
# Successfully downloaded predicted structure for UniProt ID Q6T8E9
# Successfully downloaded predicted structure for UniProt ID Q6T8E9 to output_dir/Q6T8E9.cif
# Successfully downloaded predicted structure for UniProt ID Q9QWV9 to output_dir/Q9QWV9.cif
# Successfully downloaded predicted structure for UniProt ID Q9QWV9
# Successfully downloaded predicted structure for UniProt ID Q9QWV9 to output_dir/Q9QWV9.cif
# Successfully downloaded predicted structure for UniProt ID P46892 to output_dir/P46892.cif
# Successfully downloaded predicted structure for UniProt ID P46892
# Successfully downloaded predicted structure for UniProt ID P46892 to output_dir/P46892.cif
# Successfully downloaded predicted structure for UniProt ID Q8JZM7 to output_dir/Q8JZM7.cif
# Successfully downloaded predicted structure for UniProt ID Q8JZM7
# Successfully downloaded predicted structure for UniProt ID Q8JZM7 to output_dir/Q8JZM7.cif
# Successfully downloaded predicted structure for UniProt ID Q4V8C8 to output_dir/Q4V8C8.cif
# Successfully downloaded predicted structure for UniProt ID Q4V8C8
# Successfully downloaded predicted structure for UniProt ID Q4V8C8 to output_dir/Q4V8C8.cif
# Successfully downloaded predicted structure for UniProt ID Q32PH1 to output_dir/Q32PH1.cif
# Successfully downloaded predicted structure for UniProt ID Q32PH1
# Successfully downloaded predicted structure for UniProt ID Q32PH1 to output_dir/Q32PH1.cif
# Successfully downloaded predicted structure for UniProt ID Q9BWT1 to output_dir/Q9BWT1.cif
# Successfully downloaded predicted structure for UniProt ID Q9BWT1
# Successfully downloaded predicted structure for UniProt ID Q9BWT1 to output_dir/Q9BWT1.cif
# Successfully downloaded predicted structure for UniProt ID Q9D0M2 to output_dir/Q9D0M2.cif
# Successfully downloaded predicted structure for UniProt ID Q9D0M2
# Successfully downloaded predicted structure for UniProt ID Q9D0M2 to output_dir/Q9D0M2.cif
# Successfully downloaded predicted structure for UniProt ID Q4KM91 to output_dir/Q4KM91.cif
# Successfully downloaded predicted structure for UniProt ID Q4KM91
# Successfully downloaded predicted structure for UniProt ID Q4KM91 to output_dir/Q4KM91.cif
# Successfully downloaded predicted structure for UniProt ID O19002 to output_dir/O19002.cif
# Successfully downloaded predicted structure for UniProt ID O19002
# Successfully downloaded predicted structure for UniProt ID O19002 to output_dir/O19002.cif
# Successfully downloaded predicted structure for UniProt ID Q6SLL5 to output_dir/Q6SLL5.cif
# Successfully downloaded predicted structure for UniProt ID Q6SLL5
# Successfully downloaded predicted structure for UniProt ID Q6SLL5 to output_dir/Q6SLL5.cif
# Successfully downloaded predicted structure for UniProt ID Q60439 to output_dir/Q60439.cif
# Successfully downloaded predicted structure for UniProt ID Q60439
# Successfully downloaded predicted structure for UniProt ID Q60439 to output_dir/Q60439.cif
# Successfully downloaded predicted structure for UniProt ID O19001 to output_dir/O19001.cif
# Successfully downloaded predicted structure for UniProt ID O19001
# Successfully downloaded predicted structure for UniProt ID O19001 to output_dir/O19001.cif
# Successfully downloaded predicted structure for UniProt ID P49918 to output_dir/P49918.cif
# Successfully downloaded predicted structure for UniProt ID P49918
# Successfully downloaded predicted structure for UniProt ID P49918 to output_dir/P49918.cif
# Successfully downloaded predicted structure for UniProt ID P46529 to output_dir/P46529.cif
# Successfully downloaded predicted structure for UniProt ID P46529
# ...
# Successfully downloaded predicted structure for UniProt ID Q2KI74 to output_dir/Q2KI74.cif
# Successfully downloaded predicted structure for UniProt ID Q2KI74
# Successfully downloaded predicted structure for UniProt ID Q2KI74 to output_dir/Q2KI74.cif
# Successfully downloaded predicted structure for UniProt ID Q15628 to output_dir/Q15628.cif
# Successfully downloaded predicted structure for UniProt ID Q15628
# Successfully downloaded predicted structure for UniProt ID Q15628 to output_dir/Q15628.cif
# Successfully downloaded predicted structure for UniProt ID Q3U0V2 to output_dir/Q3U0V2.cif
# Successfully downloaded predicted structure for UniProt ID Q3U0V2
# Successfully downloaded predicted structure for UniProt ID Q3U0V2 to output_dir/Q3U0V2.cif
# Successfully downloaded predicted structure for UniProt ID Q8IYM9 to output_dir/Q8IYM9.cif
# Successfully downloaded predicted structure for UniProt ID Q8IYM9
# Successfully downloaded predicted structure for UniProt ID Q8IYM9 to output_dir/Q8IYM9.cif
# Successfully downloaded predicted structure for UniProt ID P19473 to output_dir/P19473.cif
# Successfully downloaded predicted structure for UniProt ID P19473
# Successfully downloaded predicted structure for UniProt ID P19473 to output_dir/P19473.cif
# Successfully downloaded predicted structure for UniProt ID P42681 to output_dir/P42681.cif
# Successfully downloaded predicted structure for UniProt ID P42681
# Successfully downloaded predicted structure for UniProt ID P42681 to output_dir/P42681.cif
# Successfully downloaded predicted structure for UniProt ID O43818 to output_dir/O43818.cif
# Successfully downloaded predicted structure for UniProt ID O43818
# Successfully downloaded predicted structure for UniProt ID O43818 to output_dir/O43818.cif
# Successfully downloaded predicted structure for UniProt ID Q91WM3 to output_dir/Q91WM3.cif
# Successfully downloaded predicted structure for UniProt ID Q91WM3
# Successfully downloaded predicted structure for UniProt ID Q91WM3 to output_dir/Q91WM3.cif
# Successfully downloaded predicted structure for UniProt ID Q9C0C9 to output_dir/Q9C0C9.cif
# Successfully downloaded predicted structure for UniProt ID Q9C0C9
# Successfully downloaded predicted structure for UniProt ID Q9C0C9 to output_dir/Q9C0C9.cif
# Successfully downloaded predicted structure for UniProt ID A6QR55 to output_dir/A6QR55.cif
# Successfully downloaded predicted structure for UniProt ID A6QR55
# Successfully downloaded predicted structure for UniProt ID A6QR55 to output_dir/A6QR55.cif
# Successfully downloaded predicted structure for UniProt ID Q13107 to output_dir/Q13107.cif
# Successfully downloaded predicted structure for UniProt ID Q13107
# Successfully downloaded predicted structure for UniProt ID Q13107 to output_dir/Q13107.cif
# Successfully downloaded predicted structure for UniProt ID P35123 to output_dir/P35123.cif
# Successfully downloaded predicted structure for UniProt ID P35123
# Successfully downloaded predicted structure for UniProt ID P35123 to output_dir/P35123.cif
# Successfully downloaded predicted structure for UniProt ID Q5RCD3 to output_dir/Q5RCD3.cif
# Successfully downloaded predicted structure for UniProt ID Q5RCD3
# Successfully downloaded predicted structure for UniProt ID Q5RCD3 to output_dir/Q5RCD3.cif
# Successfully downloaded predicted structure for UniProt ID B2GUZ1 to output_dir/B2GUZ1.cif
# Successfully downloaded predicted structure for UniProt ID B2GUZ1
# Successfully downloaded predicted structure for UniProt ID B2GUZ1 to output_dir/B2GUZ1.cif
# Successfully downloaded predicted structure for UniProt ID Q2YDN8 to output_dir/Q2YDN8.cif
# Successfully downloaded predicted structure for UniProt ID Q2YDN8
# Successfully downloaded predicted structure for UniProt ID Q2YDN8 to output_dir/Q2YDN8.cif
# Successfully downloaded predicted structure for UniProt ID Q8IV63 to output_dir/Q8IV63.cif
# Successfully downloaded predicted structure for UniProt ID Q8IV63
# Successfully downloaded predicted structure for UniProt ID Q8IV63 to output_dir/Q8IV63.cif
# Successfully downloaded predicted structure for UniProt ID Q8K3G5 to output_dir/Q8K3G5.cif
# Successfully downloaded predicted structure for UniProt ID Q8K3G5
# Successfully downloaded predicted structure for UniProt ID Q8K3G5 to output_dir/Q8K3G5.cif
# Successfully downloaded predicted structure for UniProt ID Q9GMA3 to output_dir/Q9GMA3.cif
# Successfully downloaded predicted structure for UniProt ID Q9GMA3
# Successfully downloaded predicted structure for UniProt ID Q9GMA3 to output_dir/Q9GMA3.cif
# Successfully downloaded predicted structure for UniProt ID Q9NZR4 to output_dir/Q9NZR4.cif
# Successfully downloaded predicted structure for UniProt ID Q9NZR4
# Successfully downloaded predicted structure for UniProt ID Q9NZR4 to output_dir/Q9NZR4.cif
# Successfully downloaded predicted structure for UniProt ID Q91V10 to output_dir/Q91V10.cif
# Successfully downloaded predicted structure for UniProt ID Q91V10
# Successfully downloaded predicted structure for UniProt ID Q91V10 to output_dir/Q91V10.cif
# Successfully downloaded predicted structure for UniProt ID D2HHP1 to output_dir/D2HHP1.cif
# Successfully downloaded predicted structure for UniProt ID D2HHP1
# Successfully downloaded predicted structure for UniProt ID D2HHP1 to output_dir/D2HHP1.cif
# Successfully downloaded predicted structure for UniProt ID E2RSS3 to output_dir/E2RSS3.cif
# Successfully downloaded predicted structure for UniProt ID E2RSS3
# Successfully downloaded predicted structure for UniProt ID E2RSS3 to output_dir/E2RSS3.cif
# Successfully downloaded predicted structure for UniProt ID P0C1S8 to output_dir/P0C1S8.cif
# Successfully downloaded predicted structure for UniProt ID P0C1S8
# Successfully downloaded predicted structure for UniProt ID P0C1S8 to output_dir/P0C1S8.cif
# Successfully downloaded predicted structure for UniProt ID Q66JT0 to output_dir/Q66JT0.cif
# Successfully downloaded predicted structure for UniProt ID Q66JT0
# Successfully downloaded predicted structure for UniProt ID Q66JT0 to output_dir/Q66JT0.cif
# Successfully downloaded predicted structure for UniProt ID A4PES0 to output_dir/A4PES0.cif
# Successfully downloaded predicted structure for UniProt ID A4PES0
# Successfully downloaded predicted structure for UniProt ID A4PES0 to output_dir/A4PES0.cif
# Successfully downloaded predicted structure for UniProt ID Q9NZC7 to output_dir/Q9NZC7.cif
# Successfully downloaded predicted structure for UniProt ID Q9NZC7
# Successfully downloaded predicted structure for UniProt ID Q9NZC7 to output_dir/Q9NZC7.cif
# Successfully downloaded predicted structure for UniProt ID Q91WL8 to output_dir/Q91WL8.cif
# Successfully downloaded predicted structure for UniProt ID Q91WL8
# Successfully downloaded predicted structure for UniProt ID Q91WL8 to output_dir/Q91WL8.cif
# Successfully downloaded predicted structure for UniProt ID Q5R9W5 to output_dir/Q5R9W5.cif
# Successfully downloaded predicted structure for UniProt ID Q5R9W5
# Successfully downloaded predicted structure for UniProt ID Q5R9W5 to output_dir/Q5R9W5.cif
# Successfully downloaded predicted structure for UniProt ID P23025 to output_dir/P23025.cif
# Successfully downloaded predicted structure for UniProt ID P23025
# Successfully downloaded predicted structure for UniProt ID P23025 to output_dir/P23025.cif
# Successfully downloaded predicted structure for UniProt ID Q64267 to output_dir/Q64267.cif
# Successfully downloaded predicted structure for UniProt ID Q64267
# Successfully downloaded predicted structure for UniProt ID Q64267 to output_dir/Q64267.cif
# Successfully downloaded predicted structure for UniProt ID Q01831 to output_dir/Q01831.cif
# Successfully downloaded predicted structure for UniProt ID Q01831
# Successfully downloaded predicted structure for UniProt ID Q01831 to output_dir/Q01831.cif
# Successfully downloaded predicted structure for UniProt ID P51612 to output_dir/P51612.cif
# Successfully downloaded predicted structure for UniProt ID P51612
# Successfully downloaded predicted structure for UniProt ID P51612 to output_dir/P51612.cif
# Successfully downloaded predicted structure for UniProt ID Q9QYM7 to output_dir/Q9QYM7.cif
# Successfully downloaded predicted structure for UniProt ID Q9QYM7
# Successfully downloaded predicted structure for UniProt ID Q9QYM7 to output_dir/Q9QYM7.cif
# Successfully downloaded predicted structure for UniProt ID Q92889 to output_dir/Q92889.cif
# Successfully downloaded predicted structure for UniProt ID Q92889
# Successfully downloaded predicted structure for UniProt ID Q92889 to output_dir/Q92889.cif
# Successfully downloaded predicted structure for UniProt ID Q9QZD4 to output_dir/Q9QZD4.cif
# Successfully downloaded predicted structure for UniProt ID Q9QZD4
# Successfully downloaded predicted structure for UniProt ID Q9QZD4 to output_dir/Q9QZD4.cif
# Successfully downloaded predicted structure for UniProt ID Q65Z59 to output_dir/Q65Z59.cif
# Successfully downloaded predicted structure for UniProt ID Q65Z59
# Successfully downloaded predicted structure for UniProt ID Q65Z59 to output_dir/Q65Z59.cif
# Successfully downloaded predicted structure for UniProt ID O60688 to output_dir/O60688.cif
# Successfully downloaded predicted structure for UniProt ID O60688
# Successfully downloaded predicted structure for UniProt ID O60688 to output_dir/O60688.cif
# Successfully downloaded predicted structure for UniProt ID Q9ESC7 to output_dir/Q9ESC7.cif
# Successfully downloaded predicted structure for UniProt ID Q9ESC7
# Successfully downloaded predicted structure for UniProt ID Q9ESC7 to output_dir/Q9ESC7.cif
# Successfully downloaded predicted structure for UniProt ID Q02975 to output_dir/Q02975.cif
# Successfully downloaded predicted structure for UniProt ID Q02975
# Successfully downloaded predicted structure for UniProt ID Q02975 to output_dir/Q02975.cif
# Successfully downloaded predicted structure for UniProt ID O43829 to output_dir/O43829.cif
# Successfully downloaded predicted structure for UniProt ID O43829
# Successfully downloaded predicted structure for UniProt ID O43829 to output_dir/O43829.cif
# Successfully downloaded predicted structure for UniProt ID Q08376 to output_dir/Q08376.cif
# Successfully downloaded predicted structure for UniProt ID Q08376
# Successfully downloaded predicted structure for UniProt ID Q08376 to output_dir/Q08376.cif
# Successfully downloaded predicted structure for UniProt ID Q7Z2W4 to output_dir/Q7Z2W4.cif
# Successfully downloaded predicted structure for UniProt ID Q7Z2W4
# Successfully downloaded predicted structure for UniProt ID Q7Z2W4 to output_dir/Q7Z2W4.cif
# Successfully downloaded predicted structure for UniProt ID Q3UPF5 to output_dir/Q3UPF5.cif
# Successfully downloaded predicted structure for UniProt ID Q3UPF5
# Successfully downloaded predicted structure for UniProt ID Q3UPF5 to output_dir/Q3UPF5.cif
# Successfully downloaded predicted structure for UniProt ID Q8K3Y6 to output_dir/Q8K3Y6.cif
# Successfully downloaded predicted structure for UniProt ID Q8K3Y6
# Successfully downloaded predicted structure for UniProt ID Q8K3Y6 to output_dir/Q8K3Y6.cif
# Successfully downloaded predicted structure for UniProt ID P31629 to output_dir/P31629.cif
# Successfully downloaded predicted structure for UniProt ID P31629
# Successfully downloaded predicted structure for UniProt ID P31629 to output_dir/P31629.cif
# Failed to retrieve predicted structure for UniProt ID Q3UHF7. Status code: 404
# Error: Unable to retrieve homolog from HHpred
# Error: Unable to find a homolog for the given sequence
# Failed to retrieve predicted structure for UniProt ID Q00900. Status code: 404
# Error: Unable to retrieve homolog from HHpred
# Error: Unable to find a homolog for the given sequence
# Successfully downloaded predicted structure for UniProt ID Q5T1R4 to output_dir/Q5T1R4.cif
# Successfully downloaded predicted structure for UniProt ID Q5T1R4
# Successfully downloaded predicted structure for UniProt ID Q5T1R4 to output_dir/Q5T1R4.cif
# Successfully downloaded predicted structure for UniProt ID A2A884 to output_dir/A2A884.cif
# Successfully downloaded predicted structure for UniProt ID A2A884
# Successfully downloaded predicted structure for UniProt ID A2A884 to output_dir/A2A884.cif
# Successfully downloaded predicted structure for UniProt ID P10925 to output_dir/P10925.cif
# Successfully downloaded predicted structure for UniProt ID P10925
# Successfully downloaded predicted structure for UniProt ID P10925 to output_dir/P10925.cif
# Successfully downloaded predicted structure for UniProt ID P20662 to output_dir/P20662.cif
# Successfully downloaded predicted structure for UniProt ID P20662
# Successfully downloaded predicted structure for UniProt ID P20662 to output_dir/P20662.cif
# Successfully downloaded predicted structure for UniProt ID Q15326 to output_dir/Q15326.cif
# Successfully downloaded predicted structure for UniProt ID Q15326
# Successfully downloaded predicted structure for UniProt ID Q15326 to output_dir/Q15326.cif
# Successfully downloaded predicted structure for UniProt ID Q8R5C8 to output_dir/Q8R5C8.cif
# Successfully downloaded predicted structure for UniProt ID Q8R5C8
# Successfully downloaded predicted structure for UniProt ID Q8R5C8 to output_dir/Q8R5C8.cif
# Successfully downloaded predicted structure for UniProt ID Q9Y473 to output_dir/Q9Y473.cif
# Successfully downloaded predicted structure for UniProt ID Q9Y473
# Successfully downloaded predicted structure for UniProt ID Q9Y473 to output_dir/Q9Y473.cif
# Successfully downloaded predicted structure for UniProt ID Q32LC9 to output_dir/Q32LC9.cif
# Successfully downloaded predicted structure for UniProt ID Q32LC9
# Successfully downloaded predicted structure for UniProt ID Q32LC9 to output_dir/Q32LC9.cif
# Successfully downloaded predicted structure for UniProt ID O70524 to output_dir/O70524.cif
# Successfully downloaded predicted structure for UniProt ID O70524
# Successfully downloaded predicted structure for UniProt ID O70524 to output_dir/O70524.cif
# Successfully downloaded predicted structure for UniProt ID Q9Y3S2 to output_dir/Q9Y3S2.cif
# Successfully downloaded predicted structure for UniProt ID Q9Y3S2
# Successfully downloaded predicted structure for UniProt ID Q9Y3S2 to output_dir/Q9Y3S2.cif
# Successfully downloaded predicted structure for UniProt ID Q922H9 to output_dir/Q922H9.cif
# Successfully downloaded predicted structure for UniProt ID Q922H9
# Successfully downloaded predicted structure for UniProt ID Q922H9 to output_dir/Q922H9.cif
# Successfully downloaded predicted structure for UniProt ID Q5R9D9 to output_dir/Q5R9D9.cif
# Successfully downloaded predicted structure for UniProt ID Q5R9D9
# Successfully downloaded predicted structure for UniProt ID Q5R9D9 to output_dir/Q5R9D9.cif
# Successfully downloaded predicted structure for UniProt ID Q6ECI4 to output_dir/Q6ECI4.cif
# Successfully downloaded predicted structure for UniProt ID Q6ECI4
# Successfully downloaded predicted structure for UniProt ID Q6ECI4 to output_dir/Q6ECI4.cif
# Successfully downloaded predicted structure for UniProt ID Q5SXI5 to output_dir/Q5SXI5.cif
# Successfully downloaded predicted structure for UniProt ID Q5SXI5
# Successfully downloaded predicted structure for UniProt ID Q5SXI5 to output_dir/Q5SXI5.cif
# Successfully downloaded predicted structure for UniProt ID Q96CK0 to output_dir/Q96CK0.cif
# Successfully downloaded predicted structure for UniProt ID Q96CK0
# Successfully downloaded predicted structure for UniProt ID Q96CK0 to output_dir/Q96CK0.cif
# Successfully downloaded predicted structure for UniProt ID Q24JY4 to output_dir/Q24JY4.cif
# Successfully downloaded predicted structure for UniProt ID Q24JY4
# Successfully downloaded predicted structure for UniProt ID Q24JY4 to output_dir/Q24JY4.cif
# Successfully downloaded predicted structure for UniProt ID O43257 to output_dir/O43257.cif
# Successfully downloaded predicted structure for UniProt ID O43257
# Successfully downloaded predicted structure for UniProt ID O43257 to output_dir/O43257.cif
# Successfully downloaded predicted structure for UniProt ID Q8R331 to output_dir/Q8R331.cif
# Successfully downloaded predicted structure for UniProt ID Q8R331
# Successfully downloaded predicted structure for UniProt ID Q8R331 to output_dir/Q8R331.cif
