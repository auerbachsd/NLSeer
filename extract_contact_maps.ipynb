# %%
import numpy as np
from Bio.PDB import PDBParser
import os
import matplotlib.pyplot as plt

# %%
# Let's parse out contact maps, or graphical representations of interactions between individual atoms in amino acid side chains
# The distance cutoff is 8.0 angstroms, or 10^-10 meters. This is the typical threshold for a meaningful proximity between atoms.

def parse_contact_map(pdb_file, distance_cutoff=8.0):
    parser = PDBParser()
    structure = parser.get_structure('protein', pdb_file)
    
    # Initialize contact map matrix
    num_atoms = sum(1 for _ in structure.get_atoms())
    contact_map = np.zeros((num_atoms, num_atoms), dtype=bool)
    
    # Calculate distances and populate contact map
    for atom1 in structure.get_atoms():
        for atom2 in structure.get_atoms():
            distance = atom1 - atom2
            if distance <= distance_cutoff:
                contact_map[atom1.get_id() - 1, atom2.get_id() - 1] = True
    
    return contact_map

# %%
def generate_contact_map(pdb_file, output_dir, distance_cutoff=8.0):
    # Parse PDB file and generate contact map
    contact_map = parse_contact_map(pdb_file, distance_cutoff)
    
    # Create output directory if it doesn't exist
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    # Save contact map to output directory
    pdb_name = os.path.splitext(os.path.basename(pdb_file))[0]
    output_file = os.path.join(output_dir, f'{pdb_name}_contact_map.npy')
    np.save(output_file, contact_map)

# %%
generate_contact_map("output_dir/A7MB80.cif", "contact_map_dir")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/l_/84czh12n7tnbd478l7b1xgd40000gn/T/ipykernel_29983/298809224.py in <cell line: 1>()
# ----> 1 generate_contact_map("output_dir/A7MB80.cif", "contact_map_dir")
#
# /var/folders/l_/84czh12n7tnbd478l7b1xgd40000gn/T/ipykernel_29983/4250929669.py in generate_contact_map(pdb_file, output_dir, distance_cutoff)
#       1 def generate_contact_map(pdb_file, output_dir, distance_cutoff=8.0):
#       2     # Parse PDB file and generate contact map
# ----> 3     contact_map = parse_contact_map(pdb_file, distance_cutoff)
#       4
#       5     # Create output directory if it doesn't exist
#
# /var/folders/l_/84czh12n7tnbd478l7b1xgd40000gn/T/ipykernel_29983/580759326.py in parse_contact_map(pdb_file, distance_cutoff)
#       4 def parse_contact_map(pdb_file, distance_cutoff=8.0):
#       5     parser = PDBParser()
# ----> 6     structure = parser.get_structure('protein', pdb_file)
#       7
#       8     # Initialize contact map matrix
#
# ~/anaconda3/lib/python3.10/site-packages/Bio/PDB/PDBParser.py in get_structure(self, id, file)
#      97                 lines = handle.readlines()
#      98                 if not lines:
# ---> 99                     raise ValueError("Empty file.")
#     100                 self._parse(lines)
#     101
#
# ValueError: Empty file.

# %%
#Generate loop so these functions pass through every PDB file inside the output_dir directory.
input_dir = 'output_dir'
output_dir = 'contact_map_dir'
#Use .cif files to generate contact maps, not .pdb
for filename in os.listdir(input_dir):
    if filename.endswith('.cif'):
        pdb_file = os.path.join(input_dir, filename)
        generate_contact_map(pdb_file, output_dir)

# %%
#Purge empty contact maps and keep the informative ones. Keeping empty contact maps clogs up the directory and hinders downstream analyses.
        
def purge_empty_contact_maps(contact_map_dir):
    """
    Purge empty contact maps from the specified directory.
    
    Parameters:
        contact_map_dir (str): Path to the directory containing contact map files.
    """
    for filename in os.listdir(contact_map_dir):
        if filename.endswith('.npy'):
            contact_map_path = os.path.join(contact_map_dir, filename)
            contact_map = np.load(contact_map_path)
            if contact_map.size == 0 or contact_map.max() == 0:
                os.remove(contact_map_path)
                print(f"Empty contact map '{filename}' removed.")

purge_empty_contact_maps('contact_map_dir')
# Out:
# Empty contact map 'Q9UNZ2_contact_map.npy' removed.
# Empty contact map 'Q99PW4_contact_map.npy' removed.
# Empty contact map 'Q14188_contact_map.npy' removed.
# Empty contact map 'P58195_contact_map.npy' removed.
# Empty contact map 'Q9EQE1_contact_map.npy' removed.
# Empty contact map 'Q9C0D0_contact_map.npy' removed.
# Empty contact map 'Q96IF1_contact_map.npy' removed.
# Empty contact map 'Q9WUU8_contact_map.npy' removed.
# Empty contact map 'Q9ESK9_contact_map.npy' removed.
# Empty contact map 'Q1RMS5_contact_map.npy' removed.
# Empty contact map 'P42681_contact_map.npy' removed.
# Empty contact map 'Q8C9B9_contact_map.npy' removed.
# Empty contact map 'P15533_contact_map.npy' removed.
# Empty contact map 'Q66HD3_contact_map.npy' removed.
# Empty contact map 'P35583_contact_map.npy' removed.
# Empty contact map 'O35618_contact_map.npy' removed.
# Empty contact map 'Q309Z6_contact_map.npy' removed.
# Empty contact map 'O14776_contact_map.npy' removed.
# Empty contact map 'P55263_contact_map.npy' removed.
# Empty contact map 'Q96GQ7_contact_map.npy' removed.
# Empty contact map 'Q07243_contact_map.npy' removed.
# Empty contact map 'Q6MGB6_contact_map.npy' removed.
# Empty contact map 'Q9P016_contact_map.npy' removed.
# Empty contact map 'Q71F23_contact_map.npy' removed.
# Empty contact map 'O60356_contact_map.npy' removed.
# Empty contact map 'Q9XTA5_contact_map.npy' removed.
# Empty contact map 'P49918_contact_map.npy' removed.
# Empty contact map 'Q7YRZ8_contact_map.npy' removed.
# Empty contact map 'Q96IK5_contact_map.npy' removed.
# Empty contact map 'P48595_contact_map.npy' removed.
# Empty contact map 'P14404_contact_map.npy' removed.
# Empty contact map 'Q8BU11_contact_map.npy' removed.
# Empty contact map 'Q924A0_contact_map.npy' removed.
# Empty contact map 'Q9NZC7_contact_map.npy' removed.
# Empty contact map 'P81436_contact_map.npy' removed.
# Empty contact map 'Q5RAR6_contact_map.npy' removed.
# Empty contact map 'O94983_contact_map.npy' removed.
# Empty contact map 'Q3UR85_contact_map.npy' removed.
# Empty contact map 'Q6ZPI3_contact_map.npy' removed.
# Empty contact map 'Q9QY16_contact_map.npy' removed.
# Empty contact map 'Q9HBY8_contact_map.npy' removed.
# Empty contact map 'P59114_contact_map.npy' removed.
# Empty contact map 'O15534_contact_map.npy' removed.
# Empty contact map 'Q60547_contact_map.npy' removed.
# Empty contact map 'Q9BXN6_contact_map.npy' removed.
# Empty contact map 'A2A891_contact_map.npy' removed.
# Empty contact map 'Q5G6V9_contact_map.npy' removed.
# Empty contact map 'Q08211_contact_map.npy' removed.
# Empty contact map 'P49919_contact_map.npy' removed.
# Empty contact map 'Q99NI4_contact_map.npy' removed.
# Empty contact map 'Q9JMG7_contact_map.npy' removed.
# Empty contact map 'Q62627_contact_map.npy' removed.
# Empty contact map 'Q9QX72_contact_map.npy' removed.
# Empty contact map 'Q9WVH4_contact_map.npy' removed.
# Empty contact map 'Q8BML1_contact_map.npy' removed.
# Empty contact map 'Q99697_contact_map.npy' removed.
# Empty contact map 'P22361_contact_map.npy' removed.
# Empty contact map 'Q3T160_contact_map.npy' removed.
# Empty contact map 'B2RYN7_contact_map.npy' removed.
# Empty contact map 'Q9ULW6_contact_map.npy' removed.
# Empty contact map 'Q812D1_contact_map.npy' removed.
# Empty contact map 'Q9UHL9_contact_map.npy' removed.
# Empty contact map 'Q8IVN3_contact_map.npy' removed.
# Empty contact map 'Q13609_contact_map.npy' removed.
# Empty contact map 'Q5R591_contact_map.npy' removed.
# Empty contact map 'Q8K120_contact_map.npy' removed.
# Empty contact map 'Q8NEY8_contact_map.npy' removed.
# Empty contact map 'Q9UBZ9_contact_map.npy' removed.
# Empty contact map 'P17697_contact_map.npy' removed.
# Empty contact map 'P21291_contact_map.npy' removed.
# Empty contact map 'P15257_contact_map.npy' removed.
# Empty contact map 'Q64127_contact_map.npy' removed.
# Empty contact map 'E2RSS3_contact_map.npy' removed.
# Empty contact map 'Q5RJZ1_contact_map.npy' removed.
# Empty contact map 'O75364_contact_map.npy' removed.
# Empty contact map 'O43148_contact_map.npy' removed.
# Empty contact map 'P70351_contact_map.npy' removed.
# Empty contact map 'Q5R752_contact_map.npy' removed.
# Empty contact map 'Q5REG1_contact_map.npy' removed.
# Empty contact map 'O15131_contact_map.npy' removed.
# Empty contact map 'Q62209_contact_map.npy' removed.
# Empty contact map 'O77562_contact_map.npy' removed.
# Empty contact map 'Q9UER7_contact_map.npy' removed.
# Empty contact map 'Q9D5T7_contact_map.npy' removed.
# Empty contact map 'Q4R4I0_contact_map.npy' removed.
# Empty contact map 'Q5RKI6_contact_map.npy' removed.
# Empty contact map 'Q9EPW1_contact_map.npy' removed.
# Empty contact map 'Q9UFW8_contact_map.npy' removed.
# Empty contact map 'O88940_contact_map.npy' removed.
# Empty contact map 'Q66JQ7_contact_map.npy' removed.
# Empty contact map 'P28715_contact_map.npy' removed.
# Empty contact map 'P35227_contact_map.npy' removed.
# Empty contact map 'P18760_contact_map.npy' removed.
# Empty contact map 'Q5XIN1_contact_map.npy' removed.
# Empty contact map 'P52294_contact_map.npy' removed.
# Empty contact map 'Q9Z0X1_contact_map.npy' removed.
# Empty contact map 'Q80X82_contact_map.npy' removed.
# Empty contact map 'Q99JI1_contact_map.npy' removed.
# Empty contact map 'P28339_contact_map.npy' removed.
# Empty contact map 'Q4R633_contact_map.npy' removed.
# Empty contact map 'O95644_contact_map.npy' removed.
# Empty contact map 'Q9UBB9_contact_map.npy' removed.
# Empty contact map 'Q5EAN7_contact_map.npy' removed.
# Empty contact map 'Q9R207_contact_map.npy' removed.
# Empty contact map 'Q9JLT7_contact_map.npy' removed.
# Empty contact map 'Q5R8S3_contact_map.npy' removed.
# Empty contact map 'O43823_contact_map.npy' removed.
# Empty contact map 'Q9BZZ5_contact_map.npy' removed.
# Empty contact map 'P19447_contact_map.npy' removed.
# Empty contact map 'Q8WYA1_contact_map.npy' removed.
# Empty contact map 'O14981_contact_map.npy' removed.
# Empty contact map 'P10925_contact_map.npy' removed.
# Empty contact map 'Q8IZA3_contact_map.npy' removed.
# Empty contact map 'P52293_contact_map.npy' removed.
# Empty contact map 'Q9Z301_contact_map.npy' removed.
# Empty contact map 'Q8R5C8_contact_map.npy' removed.
# Empty contact map 'A0JNA8_contact_map.npy' removed.
# Empty contact map 'Q5R5N5_contact_map.npy' removed.
# Empty contact map 'O35973_contact_map.npy' removed.
# Empty contact map 'A7X8D4_contact_map.npy' removed.
# Empty contact map 'Q99733_contact_map.npy' removed.
# Empty contact map 'Q04207_contact_map.npy' removed.
# Empty contact map 'Q13620_contact_map.npy' removed.
# Empty contact map 'O55103_contact_map.npy' removed.
# Empty contact map 'Q4V8C8_contact_map.npy' removed.
# Empty contact map 'Q96NM4_contact_map.npy' removed.
# Empty contact map 'Q9P0K7_contact_map.npy' removed.
# Empty contact map 'Q8K2W6_contact_map.npy' removed.
# Empty contact map 'Q6T8E9_contact_map.npy' removed.
# Empty contact map 'Q64640_contact_map.npy' removed.
# Empty contact map 'Q7Z5L9_contact_map.npy' removed.
# Empty contact map 'Q0VGM9_contact_map.npy' removed.
# Empty contact map 'Q91WV0_contact_map.npy' removed.
# Empty contact map 'Q6P1J9_contact_map.npy' removed.
# Empty contact map 'Q9Z1S0_contact_map.npy' removed.
# Empty contact map 'Q3U0V2_contact_map.npy' removed.
# Empty contact map 'Q9CWL8_contact_map.npy' removed.
# Empty contact map 'Q6PKN7_contact_map.npy' removed.
# Empty contact map 'P40121_contact_map.npy' removed.
# Empty contact map 'O35344_contact_map.npy' removed.
# Empty contact map 'Q13342_contact_map.npy' removed.
# Empty contact map 'P98203_contact_map.npy' removed.
# Empty contact map 'Q5VWQ0_contact_map.npy' removed.
# Empty contact map 'Q8VEB1_contact_map.npy' removed.
# Empty contact map 'Q7Z6G8_contact_map.npy' removed.
# Empty contact map 'O55070_contact_map.npy' removed.
# Empty contact map 'O35800_contact_map.npy' removed.
# Empty contact map 'Q04206_contact_map.npy' removed.
# Empty contact map 'Q7TT18_contact_map.npy' removed.
# Empty contact map 'A2T756_contact_map.npy' removed.
# Empty contact map 'P97283_contact_map.npy' removed.
# Empty contact map 'P62966_contact_map.npy' removed.
# Empty contact map 'Q27HV0_contact_map.npy' removed.
# Empty contact map 'Q86X24_contact_map.npy' removed.
# Empty contact map 'O75940_contact_map.npy' removed.
# Empty contact map 'O88984_contact_map.npy' removed.
# Empty contact map 'Q3ZD69_contact_map.npy' removed.
# Empty contact map 'Q3B7N9_contact_map.npy' removed.
# Empty contact map 'Q9JL70_contact_map.npy' removed.
# Empty contact map 'A7X8D2_contact_map.npy' removed.
# Empty contact map 'P35226_contact_map.npy' removed.
# Empty contact map 'B1MTC3_contact_map.npy' removed.
# Empty contact map 'Q6MGA9_contact_map.npy' removed.
# Empty contact map 'Q6P3E0_contact_map.npy' removed.
# Empty contact map 'Q91ZF2_contact_map.npy' removed.
# Empty contact map 'Q9DA19_contact_map.npy' removed.
# Empty contact map 'A2A884_contact_map.npy' removed.
# Empty contact map 'P15090_contact_map.npy' removed.
# Empty contact map 'O54838_contact_map.npy' removed.
# Empty contact map 'Q8BQP9_contact_map.npy' removed.
# Empty contact map 'Q14980_contact_map.npy' removed.
# Empty contact map 'O35343_contact_map.npy' removed.
# Empty contact map 'Q7Z2E3_contact_map.npy' removed.
# Empty contact map 'Q6SLL5_contact_map.npy' removed.
# Empty contact map 'P07903_contact_map.npy' removed.
# Empty contact map 'Q4R5C0_contact_map.npy' removed.

# %%
#Visualize contact maps generated inside contact_map_dir by using matplotlib inside a function and putting that function in a for loop
#Due to lack of meaningful interactions, some contact maps may appear as blank, so we'll have to remove them for later analysis and saving space.

def plot_contact_map(contact_map, output_filename):
    if contact_map.size == 0:
        print("Empty contact map, skipping plot.")
        return
    
    plt.imshow(contact_map, cmap='binary', origin='lower')
    plt.xlabel('Residue Index')
    plt.ylabel('Residue Index')
    plt.title('Contact Map')
    plt.colorbar(label='Contact')
    plt.savefig(output_filename)
    plt.close()

# %%
# First define output directory (at least in the context of this particular notebook)
output_dir = 'contact_map_dir'
for filename in os.listdir(output_dir):
    if filename.endswith('.npy'):
        contact_map = np.load(os.path.join(output_dir, filename))
        output_filename = os.path.join(output_dir, os.path.splitext(filename)[0] + ".png")
        plot_contact_map(contact_map, output_filename)
